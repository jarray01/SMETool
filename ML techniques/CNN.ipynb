# %%
import pandas as pd
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from keras.models import Sequential
from keras.layers import Dense, Conv1D,Conv2D, Flatten
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
dataset = pd.read_csv('C:/Users/Administrateur/Desktop/terrain.csv',sep=',')
x = dataset.iloc[:, 0:3].values
y = dataset.iloc[:,3].values
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Conv2D, Flatten,Activation,Dropout,MaxPool1D,BatchNormalization
# Splitting the dataset into the Training set and Test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.7, random_state = 0)

x = x.reshape(x.shape[0],x.shape[1],1)
y = y.reshape(y.shape[0],1)
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],1)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],1)
y_train = y_train.reshape(y_train.shape[0], 1)
y_test = y_test.reshape(y_test.shape[0], 1)

# Initialising the ANN
model = Sequential()

model.add(Conv1D(64,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(Conv1D(64,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(MaxPool1D(1))

model.add(Conv1D(128,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(Conv1D(128,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(MaxPool1D(1))

model.add(Conv1D(256,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(Conv1D(256,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(Conv1D(256,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(MaxPool1D(1))

model.add(Conv1D(512,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(Conv1D(512,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(Conv1D(512,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(MaxPool1D(1))

model.add(Conv1D(512,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(Conv1D(512,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(Conv1D(512,1, input_shape = (x.shape[1],1)))
model.add(Activation('relu'))
model.add(MaxPool1D(1))


model.add(Dropout(0.5,name='dropout1'))
model.add(Flatten())
model.add(Dense(1, activation='linear'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Fitting the ANN to the Training set
model.fit(x_train, y_train, batch_size = 10, epochs = 100)

 = model.predict(x)
dfrf1 = pd.DataFrame({'Real Values':y_train, 'Predicted Values':y_pred})
model.save("CNN")
